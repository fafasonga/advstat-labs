# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
from scipy.stats import kstest
from scipy.linalg import norm
import matplotlib.pyplot as plt
from statsmodels.distributions.empirical_distribution import ECDF

# %matplotlib inline

# %%
mu,sigma = 0.07, 0.89
data = np.random.normal(mu,sigma,1000)
z =(data-mu)/sigma
value = np.cumsum(z)

# %%
def ecdf(x):
    xs = np.sort(x)
    ys = np.arange(1, len(xs)+1)/float(len(xs))
    return (xs, ys)

# %%
xs, ys = ecdf(data)
plt.plot(xs, ys, label="handwritten", marker=">", markerfacecolor='none')

cdf = ECDF(data)
plt.plot(cdf.x, cdf.y, label="statmodels", marker="<", markerfacecolor='none')

plt.legend()
plt.show()

# %%
print(stats.kstest(data,'norm'))
# Out:
# KstestResult(statistic=0.056872869030227646, pvalue=0.002976322498107864)

# %%
datas = np.cumsum(data)

# %%
plt.plot(data,datas)
